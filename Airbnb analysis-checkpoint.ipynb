# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\Data Science\Python Data Trials\Airbnb_Open_Data.csv')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11160\2101839311.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\Data Science\Python Data Trials\Airbnb_Open_Data.csv')

# %%
df.head(5)
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
df.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction year  minimum nights  number of reviews  \
# count      102385.000000   102190.000000      102416.000000
# mean         2012.487464        8.135845          27.483743
# std             5.765556       30.553781          49.508954
# min          2003.000000    -1223.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
df.nunique()
# Out:
# id                                102058
# NAME                               61281
# host id                           102057
# host_identity_verified                 2
# host name                          13190
# neighbourhood group                    7
# neighbourhood                        224
# lat                                21991
# long                               17774
# country                                1
# country code                           1
# instant_bookable                       2
# cancellation_policy                    3
# room type                              4
# Construction year                     20
# price                               1151
# service fee                          231
# minimum nights                       153
# number of reviews                    476
# last review                         2477
# reviews per month                   1016
# review rate number                     5
# calculated host listings count        78
# ...

# %%
df.value_counts()
# Out:
# id       NAME                                host id      host_identity_verified  host name  neighbourhood group  neighbourhood  lat       long       country        country code  instant_bookable  cancellation_policy  room type     Construction year  price  service fee  minimum nights  number of reviews  last review  reviews per month  review rate number  calculated host listings count  availability 365  house_rules                                                                                                                                                         license
# ...

# %%
df['host_identity_verified'].fillna('unconfirmed', inplace=True)

# %%
df['service fee'].fillna(value=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified                 0
# host name                            406
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                            0
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# ...

# %%
df['Construction year'].fillna(df['Construction year'].mean(), inplace=True)

# %%
sns.barplot(x='room type', y='Construction year', hue='host_identity_verified', data=df)
plt.figure(figsize=(40,50))

# %%
df['availability 365'].fillna(df['availability 365'].mean(), inplace=True)

# %%
df['service fee']=df['service fee'].replace('[\$,]','',regex=True).astype(float)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
sns.barplot(x='neighbourhood group', y='service fee', data=df)
plt.figure(figsize=(50,20))

# %%
df['review rate number'].fillna(df['review rate number'].mean(), inplace=True)

# %%
df['neighbourhood'].fillna(value = 'unknown', inplace=True)

# %%
sns.barplot(x='neighbourhood', y='review rate number',hue='host_identity_verified', data=df)
plt.figure(figsize=(50,30))

# %%
sns.barplot(x='neighbourhood', y='price', data=df)
plt.figure(figsize=(50,30))

# %%
df['price']=df['price'].replace('[\$,]','', regex=True).astype(float)

# %%
verified=pd.get_dummies(df['host_identity_verified'],drop_first=True)

# %%
verified
# Out:
#         verified
# 0              0
# 1              1
# 2              0
# 3              0
# 4              1
# ...          ...
# 102594         1
# 102595         0
# 102596         0
# 102597         0
# 102598         0
#
# [102599 rows x 1 columns]

# %%
df2=pd.concat([df,verified],axis=1)

# %%
df2
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df2.drop(df2.columns[[1,3,4,5,6,9]],axis=1, inplace=True)

# %%
df2
# Out:
#              id      host id       lat      long country code  \
# 0       1001254  80014485718  40.64749 -73.97237           US
# 1       1002102  52335172823  40.75362 -73.98377           US
# 2       1002403  78829239556  40.80902 -73.94190           US
# 3       1002755  85098326012  40.68514 -73.95976           US
# 4       1003689  92037596077  40.79851 -73.94399           US
# ...         ...          ...       ...       ...          ...
# 102594  6092437  12312296767  40.70862 -73.94651           US
# 102595  6092990  77864383453  40.80460 -73.96545           US
# 102596  6093542  69050334417  40.67505 -73.98045           US
# 102597  6094094  11160591270  40.74989 -73.93777           US
# 102598  6094647  68170633372  40.76807 -73.98342           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# ...

# %%
df2.drop(df2.columns[[4,5,6,7]],axis=1, inplace=True)

# %%
df2
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified      long        country  \
# 0       80014485718            unconfirmed -73.97237  United States
# ...

# %%
df2.drop(df2.columns[[9,14,15]],axis=1, inplace=True)

# %%
df2
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified      long        country  \
# 0       80014485718            unconfirmed -73.97237  United States
# ...

# %%
df2.isnull().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified                 0
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# Construction year                      0
# price                                247
# service fee                            0
# minimum nights                       409
# reviews per month                  15879
# review rate number                     0
# calculated host listings count       319
# availability 365                       0
# house_rules                        52131
# license                           102597
# verified                               0
# dtype: int64

# %%
df2['price'].fillna(df2['price'].mean(), inplace=True)

# %%
df2.isnull().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified                 0
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# Construction year                      0
# price                                  0
# service fee                            0
# minimum nights                       409
# reviews per month                  15879
# review rate number                     0
# calculated host listings count       319
# availability 365                       0
# house_rules                        52131
# license                           102597
# verified                               0
# dtype: int64

# %%
df2['price'].isnull().sum()
# Out:
# 247

# %%
df2['number of reviews'].fillna(df2['number of reviews'].mean())
# Out:
# 0           9.0
# 1          45.0
# 2           0.0
# 3         270.0
# 4           9.0
#           ...
# 102594      0.0
# 102595      1.0
# 102596      0.0
# 102597      5.0
# 102598      0.0
# Name: number of reviews, Length: 102599, dtype: float64

# %%
df2['reviews per month'].fillna(df2['reviews per month'].mean(), inplace=True)

# %%
df2['review rate number'].fillna(df2['review rate number'].mean(), inplace=True)

# %%
df2['calculated host listings count'].fillna(df2['calculated host listings count'].mean(), inplace=True)

# %%
df2.isnull().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified                 0
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# Construction year                      0
# price                                  0
# service fee                            0
# minimum nights                       409
# reviews per month                      0
# review rate number                     0
# calculated host listings count         0
# availability 365                       0
# house_rules                        52131
# license                           102597
# verified                               0
# dtype: int64

# %%
df2['minimum nights'].fillna(df2['minimum nights'].mean(), inplace=True)

# %%
df2.isnull().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified                 0
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# Construction year                      0
# price                                  0
# service fee                            0
# minimum nights                         0
# reviews per month                      0
# review rate number                     0
# calculated host listings count         0
# availability 365                       0
# house_rules                        52131
# license                           102597
# verified                               0
# dtype: int64

# %%
df3 = df2.drop(['NAME','long','country','country code','instant_bookable','cancellation_policy','house_rules','license'], axis=1)

# %%
df3
# Out:
#              id      host id  Construction year   price  service fee  \
# 0       1001254  80014485718             2020.0   966.0        193.0
# 1       1002102  52335172823             2007.0   142.0         28.0
# 2       1002403  78829239556             2005.0   620.0        124.0
# 3       1002755  85098326012             2005.0   368.0         74.0
# 4       1003689  92037596077             2009.0   204.0         41.0
# ...         ...          ...                ...     ...          ...
# 102594  6092437  12312296767             2003.0   844.0        169.0
# 102595  6092990  77864383453             2016.0   837.0        167.0
# 102596  6093542  69050334417             2009.0   988.0        198.0
# 102597  6094094  11160591270             2015.0   546.0        109.0
# 102598  6094647  68170633372             2010.0  1032.0        206.0
#
#         minimum nights  reviews per month  review rate number  \
# 0                 10.0           0.210000                 4.0
# ...

# %%
df3.drop('host_identity_verified', axis=1, inplace=True)

# %%
df3
# Out:
#              id      host id  Construction year   price  service fee  \
# 0       1001254  80014485718             2020.0   966.0        193.0
# 1       1002102  52335172823             2007.0   142.0         28.0
# 2       1002403  78829239556             2005.0   620.0        124.0
# 3       1002755  85098326012             2005.0   368.0         74.0
# 4       1003689  92037596077             2009.0   204.0         41.0
# ...         ...          ...                ...     ...          ...
# 102594  6092437  12312296767             2003.0   844.0        169.0
# 102595  6092990  77864383453             2016.0   837.0        167.0
# 102596  6093542  69050334417             2009.0   988.0        198.0
# 102597  6094094  11160591270             2015.0   546.0        109.0
# 102598  6094647  68170633372             2010.0  1032.0        206.0
#
#         minimum nights  reviews per month  review rate number  \
# 0                 10.0           0.210000                 4.0
# ...

# %%
#Decision Tree Classifier

# %%
from sklearn.model_selection import train_test_split

# %%
X=df3.drop('verified', axis=1)

# %%
y = df3['verified']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[8538 8374]
#  [8428 8518]]

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50     16912
#            1       0.50      0.50      0.50     16946
#
#     accuracy                           0.50     33858
#    macro avg       0.50      0.50      0.50     33858
# weighted avg       0.50      0.50      0.50     33858

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test, rfc_pred))
# Out:
# [[8928 7984]
#  [8857 8089]]

# %%
print(classification_report(y_test, rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.51     16912
#            1       0.50      0.48      0.49     16946
#
#     accuracy                           0.50     33858
#    macro avg       0.50      0.50      0.50     33858
# weighted avg       0.50      0.50      0.50     33858
